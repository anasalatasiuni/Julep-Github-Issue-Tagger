# %% [markdown]
# ## Task: GitHub Issue Tagger
#
# ### Overview
#
# The GitHub Issue Tagger automates the process of fetching open GitHub issues, generating concise summaries for each, classifying them against available repository labels, and automatically applying those labels back to the issues.

# %%
import uuid

AGENT_UUID = uuid.uuid4()
TASK_UUID = uuid.uuid4()

# %% [markdown]
# Creating `Julep` Client

# %%
from julep import Client
import os

JULEP_API_KEY = ""

# Create a Julep client
client = Client(api_key=JULEP_API_KEY, environment="production")

# %% [markdown]
# Creating an `agent`

# %%
# Defining the agent
name = "Robert"
about = "A github assistant."

# Create the agent
agent = client.agents.create_or_update(
    agent_id=AGENT_UUID,
    name=name,
    about=about,
    model="gpt-4o",
)

# %% [markdown]
# Defining a `Task`

# %%
import yaml


task_yaml = '''
name: "GitHub Issue Tagger"
description: "Fetch open issues via the GitHub API, summarize each one, classify for labels, and push those labels back."

input_schema:
  type: object
  properties:
    repo_owner:
      type: string
    repo_name:
      type: string
    max_issues:
      type: integer
      default: 20
  required: ["repo_owner", "repo_name"]

tools:
  - name: github_api
    type: api_call
    api_call:
      method: GET
      url: "https://api.github.com/"      # Placeholder, overridden in each subworkflow
      headers:
        Authorization: Bearer # Insert your github token here


# -------------------- fetch_issues --------------------
fetch_issues:
  - tool: github_api
    arguments:
      method: GET
      url: $ f"https://api.github.com/repos/{steps[0].input.repo_owner}/{steps[0].input.repo_name}/issues?state=open&per_page={steps[0].input.max_issues}"
  - evaluate:
      issues: |-
        $ [
          {"number": i["number"], "title": i["title"], "body": i["body"]}
          for i in steps[0].output.json
        ]


# -------------------- fetch_labels --------------------
fetch_labels:
  - tool: github_api
    arguments:
      method: GET
      url: $ f"https://api.github.com/repos/{steps[0].input.repo_owner}/{steps[0].input.repo_name}/labels"
  
  - evaluate:
      all_labels: $ [label.name for label in steps[0].output.json]
  

# ------------------ summarize_issue -------------------
summarize_issue:
  - prompt:
    - role: user
      content: |-
        $ f"""
        Issue #{steps[0].input.issue.number}: {steps[0].input.issue.title}

        {steps[0].input.issue.body}

        Write a concise (1-3 sentence) summary of this issue.
        """
    unwrap: true

# ------------------ classify_issue ------------------
classify_issue:
  - prompt:
    - role: user
      content: |- 
        $ f"""
        Given this issue summary, suggest relevant GitHub labels as a JSON array.
        Only output JSON, e.g. ["bug","documentation"].

        Summary: {steps[0].input.summary}
        Available labels: {steps[0].input.all_labels}
        Note that you can only use available labels.
        """
    unwrap: true
  - evaluate:
      labels: $ load_json(steps[0].output.replace("```json", "").replace("```", ""))

# ------------------ apply_labels ------------------
apply_labels:
  - tool: github_api
    arguments:
      method: POST    
      url: $ f"https://api.github.com/repos/{steps[0].input.repo_owner}/{steps[0].input.repo_name}/issues/{steps[0].input.issue_number}/labels"
      json:
        labels: $ steps[0].input.labels

main:
  - workflow: fetch_issues
    arguments:
      repo_owner: $ steps[0].input.repo_owner
      repo_name:  $ steps[0].input.repo_name
      max_issues: $ steps[0].input.max_issues

  - workflow: fetch_labels
    arguments:
      repo_owner: $ steps[0].input.repo_owner
      repo_name:  $ steps[0].input.repo_name

  - over: $ steps[0].output.issues
    parallelism: 5
    map:
      workflow: summarize_issue
      arguments:
        issue: $ _

  - over: $ steps[2].output
    parallelism: 5
    map:
      workflow: classify_issue
      arguments:
        summary: $ _
        all_labels: $ steps[1].output.all_labels
  
  - evaluate:
      list_of_labels: $ _
      list_of_issues: $ steps[0].output.issues
    
  - evaluate:
      classified_issues: $ list(zip(_.list_of_labels, _.list_of_issues))
  
  - over: $ _.classified_issues
    parallelism: 5
    map:
      workflow: apply_labels
      arguments:
        repo_owner:    $ steps[0].input.repo_owner
        repo_name:     $ steps[0].input.repo_name
        issue_number:  $ _[1].number
        labels:        $ _[0].labels
'''


task_def=yaml.safe_load(task_yaml)

# %%
task = client.tasks.create_or_update(
    task_id=TASK_UUID,
    agent_id=AGENT_UUID,
    **task_def
)

# %% [markdown]
# Creating an `Execution`

# %%
execution = client.executions.create(
    task_id=task.id,
    input={
        "repo_owner": "anasalatasiuni",
        "repo_name": "Julep-Github-Issue-Tagger",
        "max_issues": 2
    }
    
)

# %% [markdown]
# Listing `Transitions`

# %%
transitions = []
of = 0

while new_transitions:= client.executions.transitions.list(execution.id, limit=100, offset=of).items:
    transitions.extend(new_transitions)
    of += 100

for i, transition in enumerate(transitions):
    print(f"Transition index: {len(transitions) - i}, type: {transition.type}, current: {transition.current}, next: {transition.next}")
    print(transition.output)
    print("-" * 50)
# Out:
# Transition index: 48, type: finish, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=6, workflow='main'), next: None
# [{'json': [{'id': 8600760509, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/labels/enhancement', 'name': 'enhancement', 'color': 'a2eeef', 'default': True, 'node_id': 'LA_kwDOOoq64c8AAAACAKUwvQ', 'description': 'New feature or request'}], 'content': '', 'headers': {'date': 'Wed, 14 May 2025 15:34:07 GMT', 'etag': 'W/"8c29fa464027c93c9d4b82032e489ff563d61cc1c89cff3eeb5dac7f03db34ff"', 'vary': 'Accept, Authorization, Cookie, X-GitHub-OTP,Accept-Encoding, Accept, X-Requested-With', 'server': 'github.com', 'content-type': 'application/json; charset=utf-8', 'cache-control': 'private, max-age=60, s-maxage=60', 'x-oauth-scopes': 'admin:enterprise, admin:gpg_key, admin:org, admin:org_hook, admin:public_key, admin:repo_hook, admin:ssh_signing_key, audit_log, codespace, copilot, delete:packages, gist, notifications, project, repo, user, workflow, write:discussion, write:network_configurations, write:packages', 'referrer-policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'x-frame-options': 'deny', 'content-encoding': 'gzip', 'x-ratelimit-used': '12', 'x-xss-protection': '0', 'transfer-encoding': 'chunked', 'x-ratelimit-limit': '5000', 'x-ratelimit-reset': '1747238377', 'x-github-media-type': 'github.v3; format=json', 'x-github-request-id': 'C974:397A46:1BE414:37F492:6824B7EE', 'x-ratelimit-resource': 'core', 'x-ratelimit-remaining': '4988', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none'", 'x-accepted-oauth-scopes': '', 'strict-transport-security': 'max-age=31536000; includeSubdomains; preload', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'x-github-api-version-selected': '2022-11-28', 'github-authentication-token-expiration': '2025-06-11 13:41:37 UTC'}, 'status_code': 200}, {'json': [{'id': 8600760474, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/labels/bug', 'name': 'bug', 'color': 'd73a4a', 'default': True, 'node_id': 'LA_kwDOOoq64c8AAAACAKUwmg', 'description': "Something isn't working"}, {'id': 8600760509, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/labels/enhancement', 'name': 'enhancement', 'color': 'a2eeef', 'default': True, 'node_id': 'LA_kwDOOoq64c8AAAACAKUwvQ', 'description': 'New feature or request'}], 'content': '...', 'headers': {'date': 'Wed, 14 May 2025 15:34:07 GMT', 'etag': 'W/"e61ff5b4c488cee76601e9537299457876483f86cd37341fb1a89735f4679fdc"', 'vary': 'Accept, Authorization, Cookie, X-GitHub-OTP,Accept-Encoding, Accept, X-Requested-With', 'server': 'github.com', 'content-type': 'application/json; charset=utf-8', 'cache-control': 'private, max-age=60, s-maxage=60', 'x-oauth-scopes': 'admin:enterprise, admin:gpg_key, admin:org, admin:org_hook, admin:public_key, admin:repo_hook, admin:ssh_signing_key, audit_log, codespace, copilot, delete:packages, gist, notifications, project, repo, user, workflow, write:discussion, write:network_configurations, write:packages', 'referrer-policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'x-frame-options': 'deny', 'content-encoding': 'gzip', 'x-ratelimit-used': '13', 'x-xss-protection': '0', 'transfer-encoding': 'chunked', 'x-ratelimit-limit': '5000', 'x-ratelimit-reset': '1747238377', 'x-github-media-type': 'github.v3; format=json', 'x-github-request-id': 'BD02:DAA85:1C13B6:382D6D:6824B7EE' ...
# --------------------------------------------------
# Transition index: 47, type: finish_branch, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[6].mapreduce[0][1]'), next: None
# {'json': [{'id': 8600760474, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/labels/bug', 'name': 'bug', 'color': 'd73a4a', 'default': True, 'node_id': 'LA_kwDOOoq64c8AAAACAKUwmg', 'description': "Something isn't working"}, {'id': 8600760509, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/labels/enhancement', 'name': 'enhancement', 'color': 'a2eeef', 'default': True, 'node_id': 'LA_kwDOOoq64c8AAAACAKUwvQ', 'description': 'New feature or request'}], 'content': '...', 'headers': {'date': 'Wed, 14 May 2025 15:34:07 GMT', 'etag': 'W/"e61ff5b4c488cee76601e9537299457876483f86cd37341fb1a89735f4679fdc"', 'vary': 'Accept, Authorization, Cookie, X-GitHub-OTP,Accept-Encoding, Accept, X-Requested-With', 'server': 'github.com', 'content-type': 'application/json; charset=utf-8', 'cache-control': 'private, max-age=60, s-maxage=60', 'x-oauth-scopes': 'admin:enterprise, admin:gpg_key, admin:org, admin:org_hook, admin:public_key, admin:repo_hook, admin:ssh_signing_key, audit_log, codespace, copilot, delete:packages, gist, notifications, project, repo, user, workflow, write:discussion, write:network_configurations, write:packages', 'referrer-policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'x-frame-options': 'deny', 'content-encoding': 'gzip', 'x-ratelimit-used': '13', 'x-xss-protection': '0', 'transfer-encoding': 'chunked', 'x-ratelimit-limit': '5000', 'x-ratelimit-reset': '1747238377', 'x-github-media-type': 'github.v3; format=json', 'x-github-request-id': 'BD02:DAA85:1C13B6:382D6D:6824B7EE', 'x-ratelimit-resource': 'core', 'x-ratelimit-remaining': '4987', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none'", 'x-accepted-oauth-scopes': '', 'strict-transport-security': 'max-age=31536000; includeSubdomains; preload', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'x-github-api-version-selected': '2022-11-28', 'github-authentication-token-expiration': '2025-06-11 13:41:37 UTC'}, 'status_code': 200}
# --------------------------------------------------
# Transition index: 46, type: finish_branch, current: Current(scope_id='06824b7e-e2e4-78ee-8000-dd707b9bfd66', step=0, workflow='apply_labels'), next: None
# {'json': [{'id': 8600760474, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/labels/bug', 'name': 'bug', 'color': 'd73a4a', 'default': True, 'node_id': 'LA_kwDOOoq64c8AAAACAKUwmg', 'description': "Something isn't working"}, {'id': 8600760509, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/labels/enhancement', 'name': 'enhancement', 'color': 'a2eeef', 'default': True, 'node_id': 'LA_kwDOOoq64c8AAAACAKUwvQ', 'description': 'New feature or request'}], 'content': '...', 'headers': {'date': 'Wed, 14 May 2025 15:34:07 GMT', 'etag': 'W/"e61ff5b4c488cee76601e9537299457876483f86cd37341fb1a89735f4679fdc"', 'vary': 'Accept, Authorization, Cookie, X-GitHub-OTP,Accept-Encoding, Accept, X-Requested-With', 'server': 'github.com', 'content-type': 'application/json; charset=utf-8', 'cache-control': 'private, max-age=60, s-maxage=60', 'x-oauth-scopes': 'admin:enterprise, admin:gpg_key, admin:org, admin:org_hook, admin:public_key, admin:repo_hook, admin:ssh_signing_key, audit_log, codespace, copilot, delete:packages, gist, notifications, project, repo, user, workflow, write:discussion, write:network_configurations, write:packages', 'referrer-policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'x-frame-options': 'deny', 'content-encoding': 'gzip', 'x-ratelimit-used': '13', 'x-xss-protection': '0', 'transfer-encoding': 'chunked', 'x-ratelimit-limit': '5000', 'x-ratelimit-reset': '1747238377', 'x-github-media-type': 'github.v3; format=json', 'x-github-request-id': 'BD02:DAA85:1C13B6:382D6D:6824B7EE', 'x-ratelimit-resource': 'core', 'x-ratelimit-remaining': '4987', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none'", 'x-accepted-oauth-scopes': '', 'strict-transport-security': 'max-age=31536000; includeSubdomains; preload', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'x-github-api-version-selected': '2022-11-28', 'github-authentication-token-expiration': '2025-06-11 13:41:37 UTC'}, 'status_code': 200}
# --------------------------------------------------
# Transition index: 45, type: finish_branch, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[6].mapreduce[0][0]'), next: None
# {'json': [{'id': 8600760509, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/labels/enhancement', 'name': 'enhancement', 'color': 'a2eeef', 'default': True, 'node_id': 'LA_kwDOOoq64c8AAAACAKUwvQ', 'description': 'New feature or request'}], 'content': '', 'headers': {'date': 'Wed, 14 May 2025 15:34:07 GMT', 'etag': 'W/"8c29fa464027c93c9d4b82032e489ff563d61cc1c89cff3eeb5dac7f03db34ff"', 'vary': 'Accept, Authorization, Cookie, X-GitHub-OTP,Accept-Encoding, Accept, X-Requested-With', 'server': 'github.com', 'content-type': 'application/json; charset=utf-8', 'cache-control': 'private, max-age=60, s-maxage=60', 'x-oauth-scopes': 'admin:enterprise, admin:gpg_key, admin:org, admin:org_hook, admin:public_key, admin:repo_hook, admin:ssh_signing_key, audit_log, codespace, copilot, delete:packages, gist, notifications, project, repo, user, workflow, write:discussion, write:network_configurations, write:packages', 'referrer-policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'x-frame-options': 'deny', 'content-encoding': 'gzip', 'x-ratelimit-used': '12', 'x-xss-protection': '0', 'transfer-encoding': 'chunked', 'x-ratelimit-limit': '5000', 'x-ratelimit-reset': '1747238377', 'x-github-media-type': 'github.v3; format=json', 'x-github-request-id': 'C974:397A46:1BE414:37F492:6824B7EE', 'x-ratelimit-resource': 'core', 'x-ratelimit-remaining': '4988', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none'", 'x-accepted-oauth-scopes': '', 'strict-transport-security': 'max-age=31536000; includeSubdomains; preload', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'x-github-api-version-selected': '2022-11-28', 'github-authentication-token-expiration': '2025-06-11 13:41:37 UTC'}, 'status_code': 200}
# --------------------------------------------------
# Transition index: 44, type: finish_branch, current: Current(scope_id='06824b7e-e0b9-72df-8000-c70543bcdc9a', step=0, workflow='apply_labels'), next: None
# {'json': [{'id': 8600760509, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/labels/enhancement', 'name': 'enhancement', 'color': 'a2eeef', 'default': True, 'node_id': 'LA_kwDOOoq64c8AAAACAKUwvQ', 'description': 'New feature or request'}], 'content': '', 'headers': {'date': 'Wed, 14 May 2025 15:34:07 GMT', 'etag': 'W/"8c29fa464027c93c9d4b82032e489ff563d61cc1c89cff3eeb5dac7f03db34ff"', 'vary': 'Accept, Authorization, Cookie, X-GitHub-OTP,Accept-Encoding, Accept, X-Requested-With', 'server': 'github.com', 'content-type': 'application/json; charset=utf-8', 'cache-control': 'private, max-age=60, s-maxage=60', 'x-oauth-scopes': 'admin:enterprise, admin:gpg_key, admin:org, admin:org_hook, admin:public_key, admin:repo_hook, admin:ssh_signing_key, audit_log, codespace, copilot, delete:packages, gist, notifications, project, repo, user, workflow, write:discussion, write:network_configurations, write:packages', 'referrer-policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'x-frame-options': 'deny', 'content-encoding': 'gzip', 'x-ratelimit-used': '12', 'x-xss-protection': '0', 'transfer-encoding': 'chunked', 'x-ratelimit-limit': '5000', 'x-ratelimit-reset': '1747238377', 'x-github-media-type': 'github.v3; format=json', 'x-github-request-id': 'C974:397A46:1BE414:37F492:6824B7EE', 'x-ratelimit-resource': 'core', 'x-ratelimit-remaining': '4988', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none'", 'x-accepted-oauth-scopes': '', 'strict-transport-security': 'max-age=31536000; includeSubdomains; preload', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'x-github-api-version-selected': '2022-11-28', 'github-authentication-token-expiration': '2025-06-11 13:41:37 UTC'}, 'status_code': 200}
# --------------------------------------------------
# Transition index: 43, type: init_branch, current: Current(scope_id='06824b7e-e2e4-78ee-8000-dd707b9bfd66', step=0, workflow='apply_labels'), next: Next(scope_id='06824b7e-e2e4-78ee-8000-dd707b9bfd66', step=0, workflow='apply_labels')
# {'labels': ['bug', 'enhancement'], 'repo_name': 'Julep-Github-Issue-Tagger', 'repo_owner': 'anasalatasiuni', 'issue_number': 1}
# --------------------------------------------------
# Transition index: 42, type: init_branch, current: Current(scope_id='06824b7e-e0b9-72df-8000-c70543bcdc9a', step=0, workflow='apply_labels'), next: Next(scope_id='06824b7e-e0b9-72df-8000-c70543bcdc9a', step=0, workflow='apply_labels')
# {'labels': ['enhancement'], 'repo_name': 'Julep-Github-Issue-Tagger', 'repo_owner': 'anasalatasiuni', 'issue_number': 2}
# --------------------------------------------------
# Transition index: 41, type: step, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[6].mapreduce[0][1]'), next: Next(scope_id='06824b7e-e2e4-78ee-8000-dd707b9bfd66', step=0, workflow='apply_labels')
# {'labels': ['bug', 'enhancement'], 'repo_name': 'Julep-Github-Issue-Tagger', 'repo_owner': 'anasalatasiuni', 'issue_number': 1}
# --------------------------------------------------
# Transition index: 40, type: step, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[6].mapreduce[0][0]'), next: Next(scope_id='06824b7e-e0b9-72df-8000-c70543bcdc9a', step=0, workflow='apply_labels')
# {'labels': ['enhancement'], 'repo_name': 'Julep-Github-Issue-Tagger', 'repo_owner': 'anasalatasiuni', 'issue_number': 2}
# --------------------------------------------------
# Transition index: 39, type: init_branch, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[6].mapreduce[0][0]'), next: Next(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[6].mapreduce[0][0]')
# [{'labels': ['enhancement']}, {'body': '**Description**  \nCurrently, the tool only outputs CSV to stdout. For easier integration with other systems, it would be great to add a `--format json` option that emits JSON.\n\n**Use Case**  \nAllows downstream scripts or services to consume structured JSON output without an extra CSV→JSON conversion step.\n\n**Proposed Solution**  \n1. Add a `--format`/`-f` CLI flag with choices `csv` (default) and `json`.  \n2. Branch in the output routine:  \n   - If `csv`, use the existing writer.  \n   - If `json`, build a list of dicts and call `json.dumps(..., indent=2)`.  \n\n**Alternatives Considered**  \n- Providing a separate `csv-to-json` helper script (less discoverable and requires an extra step).  \n', 'title': 'Add support for JSON output format', 'number': 2}]
# --------------------------------------------------
# Transition index: 38, type: init_branch, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[6].mapreduce[0][1]'), next: Next(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[6].mapreduce[0][1]')
# [{'labels': ['bug', 'enhancement']}, {'body': '**Description**  \nRunning the CLI without any arguments causes an unhandled exception and stack trace. Instead, it should display usage help or a clear error message.\n\n**Steps to Reproduce**  \n1. Clone the repo  \n2. Run `python main.py` without any flags or parameters  \n3. Observe an uncaught `IndexError: list index out of range`  \n\n**Expected Behavior**  \nThe CLI prints the help/usage text and exits with an error code (e.g. `exit 1`) rather than crashing.\n\n**Environment**  \n- Python 3.9+  \n- Tested on macOS 12 and Ubuntu 22.04  \n', 'title': 'CLI crashes when no arguments are provided', 'number': 1}]
# --------------------------------------------------
# Transition index: 37, type: step, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=5, workflow='main'), next: Next(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=6, workflow='main')
# {'classified_issues': [[{'labels': ['enhancement']}, {'body': '**Description**  \nCurrently, the tool only outputs CSV to stdout. For easier integration with other systems, it would be great to add a `--format json` option that emits JSON.\n\n**Use Case**  \nAllows downstream scripts or services to consume structured JSON output without an extra CSV→JSON conversion step.\n\n**Proposed Solution**  \n1. Add a `--format`/`-f` CLI flag with choices `csv` (default) and `json`.  \n2. Branch in the output routine:  \n   - If `csv`, use the existing writer.  \n   - If `json`, build a list of dicts and call `json.dumps(..., indent=2)`.  \n\n**Alternatives Considered**  \n- Providing a separate `csv-to-json` helper script (less discoverable and requires an extra step).  \n', 'title': 'Add support for JSON output format', 'number': 2}], [{'labels': ['bug', 'enhancement']}, {'body': '**Description**  \nRunning the CLI without any arguments causes an unhandled exception and stack trace. Instead, it should display usage help or a clear error message.\n\n**Steps to Reproduce**  \n1. Clone the repo  \n2. Run `python main.py` without any flags or parameters  \n3. Observe an uncaught `IndexError: list index out of range`  \n\n**Expected Behavior**  \nThe CLI prints the help/usage text and exits with an error code (e.g. `exit 1`) rather than crashing.\n\n**Environment**  \n- Python 3.9+  \n- Tested on macOS 12 and Ubuntu 22.04  \n', 'title': 'CLI crashes when no arguments are provided', 'number': 1}]]}
# --------------------------------------------------
# Transition index: 36, type: step, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=4, workflow='main'), next: Next(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=5, workflow='main')
# {'list_of_issues': [{'body': '**Description**  \nCurrently, the tool only outputs CSV to stdout. For easier integration with other systems, it would be great to add a `--format json` option that emits JSON.\n\n**Use Case**  \nAllows downstream scripts or services to consume structured JSON output without an extra CSV→JSON conversion step.\n\n**Proposed Solution**  \n1. Add a `--format`/`-f` CLI flag with choices `csv` (default) and `json`.  \n2. Branch in the output routine:  \n   - If `csv`, use the existing writer.  \n   - If `json`, build a list of dicts and call `json.dumps(..., indent=2)`.  \n\n**Alternatives Considered**  \n- Providing a separate `csv-to-json` helper script (less discoverable and requires an extra step).  \n', 'title': 'Add support for JSON output format', 'number': 2}, {'body': '**Description**  \nRunning the CLI without any arguments causes an unhandled exception and stack trace. Instead, it should display usage help or a clear error message.\n\n**Steps to Reproduce**  \n1. Clone the repo  \n2. Run `python main.py` without any flags or parameters  \n3. Observe an uncaught `IndexError: list index out of range`  \n\n**Expected Behavior**  \nThe CLI prints the help/usage text and exits with an error code (e.g. `exit 1`) rather than crashing.\n\n**Environment**  \n- Python 3.9+  \n- Tested on macOS 12 and Ubuntu 22.04  \n', 'title': 'CLI crashes when no arguments are provided', 'number': 1}], 'list_of_labels': [{'labels': ['enhancement']}, {'labels': ['bug', 'enhancement']}]}
# --------------------------------------------------
# Transition index: 35, type: step, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=3, workflow='main'), next: Next(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=4, workflow='main')
# [{'labels': ['enhancement']}, {'labels': ['bug', 'enhancement']}]
# --------------------------------------------------
# Transition index: 34, type: finish_branch, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[3].mapreduce[0][1]'), next: None
# {'labels': ['bug', 'enhancement']}
# --------------------------------------------------
# Transition index: 33, type: finish_branch, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[3].mapreduce[0][0]'), next: None
# {'labels': ['enhancement']}
# --------------------------------------------------
# Transition index: 32, type: finish_branch, current: Current(scope_id='06824b7e-a9c1-7546-8000-2126dfc29b01', step=1, workflow='classify_issue'), next: None
# {'labels': ['bug', 'enhancement']}
# --------------------------------------------------
# Transition index: 31, type: finish_branch, current: Current(scope_id='06824b7e-aa02-77bd-8000-ea46804b2ffc', step=1, workflow='classify_issue'), next: None
# {'labels': ['enhancement']}
# --------------------------------------------------
# Transition index: 30, type: step, current: Current(scope_id='06824b7e-a9c1-7546-8000-2126dfc29b01', step=0, workflow='classify_issue'), next: Next(scope_id='06824b7e-a9c1-7546-8000-2126dfc29b01', step=1, workflow='classify_issue')
# ```json
# ["bug", "enhancement"]
# ```
# --------------------------------------------------
# Transition index: 29, type: step, current: Current(scope_id='06824b7e-aa02-77bd-8000-ea46804b2ffc', step=0, workflow='classify_issue'), next: Next(scope_id='06824b7e-aa02-77bd-8000-ea46804b2ffc', step=1, workflow='classify_issue')
# ```json
# ["enhancement"]
# ```
# --------------------------------------------------
# Transition index: 28, type: init_branch, current: Current(scope_id='06824b7e-aa02-77bd-8000-ea46804b2ffc', step=0, workflow='classify_issue'), next: Next(scope_id='06824b7e-aa02-77bd-8000-ea46804b2ffc', step=0, workflow='classify_issue')
# {'summary': 'This issue proposes adding a `--format json` option to the tool, enabling it to output data in JSON format in addition to the current CSV format. This enhancement will facilitate easier integration with other systems by eliminating the need for an extra CSV to JSON conversion step. The solution involves adding a CLI flag to choose between `csv` and `json`, and modifying the output routine accordingly.', 'all_labels': ['bug', 'documentation', 'duplicate', 'enhancement', 'good first issue', 'help wanted', 'invalid', 'question', 'wontfix']}
# --------------------------------------------------
# Transition index: 27, type: init_branch, current: Current(scope_id='06824b7e-a9c1-7546-8000-2126dfc29b01', step=0, workflow='classify_issue'), next: Next(scope_id='06824b7e-a9c1-7546-8000-2126dfc29b01', step=0, workflow='classify_issue')
# {'summary': 'The CLI crashes with an unhandled `IndexError` when executed without any arguments, instead of displaying helpful usage information or an error message. This behavior deviates from the expected functionality where the CLI should print the help text and exit with an error code. This issue occurs on both macOS 12 and Ubuntu 22.04 with Python 3.9+.', 'all_labels': ['bug', 'documentation', 'duplicate', 'enhancement', 'good first issue', 'help wanted', 'invalid', 'question', 'wontfix']}
# --------------------------------------------------
# Transition index: 26, type: step, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[3].mapreduce[0][0]'), next: Next(scope_id='06824b7e-aa02-77bd-8000-ea46804b2ffc', step=0, workflow='classify_issue')
# {'summary': 'This issue proposes adding a `--format json` option to the tool, enabling it to output data in JSON format in addition to the current CSV format. This enhancement will facilitate easier integration with other systems by eliminating the need for an extra CSV to JSON conversion step. The solution involves adding a CLI flag to choose between `csv` and `json`, and modifying the output routine accordingly.', 'all_labels': ['bug', 'documentation', 'duplicate', 'enhancement', 'good first issue', 'help wanted', 'invalid', 'question', 'wontfix']}
# --------------------------------------------------
# Transition index: 25, type: step, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[3].mapreduce[0][1]'), next: Next(scope_id='06824b7e-a9c1-7546-8000-2126dfc29b01', step=0, workflow='classify_issue')
# {'summary': 'The CLI crashes with an unhandled `IndexError` when executed without any arguments, instead of displaying helpful usage information or an error message. This behavior deviates from the expected functionality where the CLI should print the help text and exit with an error code. This issue occurs on both macOS 12 and Ubuntu 22.04 with Python 3.9+.', 'all_labels': ['bug', 'documentation', 'duplicate', 'enhancement', 'good first issue', 'help wanted', 'invalid', 'question', 'wontfix']}
# --------------------------------------------------
# Transition index: 24, type: init_branch, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[3].mapreduce[0][0]'), next: Next(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[3].mapreduce[0][0]')
# This issue proposes adding a `--format json` option to the tool, enabling it to output data in JSON format in addition to the current CSV format. This enhancement will facilitate easier integration with other systems by eliminating the need for an extra CSV to JSON conversion step. The solution involves adding a CLI flag to choose between `csv` and `json`, and modifying the output routine accordingly.
# --------------------------------------------------
# Transition index: 23, type: init_branch, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[3].mapreduce[0][1]'), next: Next(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[3].mapreduce[0][1]')
# The CLI crashes with an unhandled `IndexError` when executed without any arguments, instead of displaying helpful usage information or an error message. This behavior deviates from the expected functionality where the CLI should print the help text and exit with an error code. This issue occurs on both macOS 12 and Ubuntu 22.04 with Python 3.9+.
# --------------------------------------------------
# Transition index: 22, type: step, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=2, workflow='main'), next: Next(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=3, workflow='main')
# ['This issue proposes adding a `--format json` option to the tool, enabling it to output data in JSON format in addition to the current CSV format. This enhancement will facilitate easier integration with other systems by eliminating the need for an extra CSV to JSON conversion step. The solution involves adding a CLI flag to choose between `csv` and `json`, and modifying the output routine accordingly.', 'The CLI crashes with an unhandled `IndexError` when executed without any arguments, instead of displaying helpful usage information or an error message. This behavior deviates from the expected functionality where the CLI should print the help text and exit with an error code. This issue occurs on both macOS 12 and Ubuntu 22.04 with Python 3.9+.']
# --------------------------------------------------
# Transition index: 21, type: finish_branch, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[2].mapreduce[0][0]'), next: None
# This issue proposes adding a `--format json` option to the tool, enabling it to output data in JSON format in addition to the current CSV format. This enhancement will facilitate easier integration with other systems by eliminating the need for an extra CSV to JSON conversion step. The solution involves adding a CLI flag to choose between `csv` and `json`, and modifying the output routine accordingly.
# --------------------------------------------------
# Transition index: 20, type: finish_branch, current: Current(scope_id='06824b7e-6a70-724e-8000-9bfff19b28d5', step=0, workflow='summarize_issue'), next: None
# This issue proposes adding a `--format json` option to the tool, enabling it to output data in JSON format in addition to the current CSV format. This enhancement will facilitate easier integration with other systems by eliminating the need for an extra CSV to JSON conversion step. The solution involves adding a CLI flag to choose between `csv` and `json`, and modifying the output routine accordingly.
# --------------------------------------------------
# Transition index: 19, type: finish_branch, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[2].mapreduce[0][1]'), next: None
# The CLI crashes with an unhandled `IndexError` when executed without any arguments, instead of displaying helpful usage information or an error message. This behavior deviates from the expected functionality where the CLI should print the help text and exit with an error code. This issue occurs on both macOS 12 and Ubuntu 22.04 with Python 3.9+.
# --------------------------------------------------
# Transition index: 18, type: finish_branch, current: Current(scope_id='06824b7e-6aa8-70e4-8000-a036191b276a', step=0, workflow='summarize_issue'), next: None
# The CLI crashes with an unhandled `IndexError` when executed without any arguments, instead of displaying helpful usage information or an error message. This behavior deviates from the expected functionality where the CLI should print the help text and exit with an error code. This issue occurs on both macOS 12 and Ubuntu 22.04 with Python 3.9+.
# --------------------------------------------------
# Transition index: 17, type: init_branch, current: Current(scope_id='06824b7e-6aa8-70e4-8000-a036191b276a', step=0, workflow='summarize_issue'), next: Next(scope_id='06824b7e-6aa8-70e4-8000-a036191b276a', step=0, workflow='summarize_issue')
# {'issue': {'body': '**Description**  \nRunning the CLI without any arguments causes an unhandled exception and stack trace. Instead, it should display usage help or a clear error message.\n\n**Steps to Reproduce**  \n1. Clone the repo  \n2. Run `python main.py` without any flags or parameters  \n3. Observe an uncaught `IndexError: list index out of range`  \n\n**Expected Behavior**  \nThe CLI prints the help/usage text and exits with an error code (e.g. `exit 1`) rather than crashing.\n\n**Environment**  \n- Python 3.9+  \n- Tested on macOS 12 and Ubuntu 22.04  \n', 'title': 'CLI crashes when no arguments are provided', 'number': 1}}
# --------------------------------------------------
# Transition index: 16, type: init_branch, current: Current(scope_id='06824b7e-6a70-724e-8000-9bfff19b28d5', step=0, workflow='summarize_issue'), next: Next(scope_id='06824b7e-6a70-724e-8000-9bfff19b28d5', step=0, workflow='summarize_issue')
# {'issue': {'body': '**Description**  \nCurrently, the tool only outputs CSV to stdout. For easier integration with other systems, it would be great to add a `--format json` option that emits JSON.\n\n**Use Case**  \nAllows downstream scripts or services to consume structured JSON output without an extra CSV→JSON conversion step.\n\n**Proposed Solution**  \n1. Add a `--format`/`-f` CLI flag with choices `csv` (default) and `json`.  \n2. Branch in the output routine:  \n   - If `csv`, use the existing writer.  \n   - If `json`, build a list of dicts and call `json.dumps(..., indent=2)`.  \n\n**Alternatives Considered**  \n- Providing a separate `csv-to-json` helper script (less discoverable and requires an extra step).  \n', 'title': 'Add support for JSON output format', 'number': 2}}
# --------------------------------------------------
# Transition index: 15, type: step, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[2].mapreduce[0][1]'), next: Next(scope_id='06824b7e-6aa8-70e4-8000-a036191b276a', step=0, workflow='summarize_issue')
# {'issue': {'body': '**Description**  \nRunning the CLI without any arguments causes an unhandled exception and stack trace. Instead, it should display usage help or a clear error message.\n\n**Steps to Reproduce**  \n1. Clone the repo  \n2. Run `python main.py` without any flags or parameters  \n3. Observe an uncaught `IndexError: list index out of range`  \n\n**Expected Behavior**  \nThe CLI prints the help/usage text and exits with an error code (e.g. `exit 1`) rather than crashing.\n\n**Environment**  \n- Python 3.9+  \n- Tested on macOS 12 and Ubuntu 22.04  \n', 'title': 'CLI crashes when no arguments are provided', 'number': 1}}
# --------------------------------------------------
# Transition index: 14, type: step, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[2].mapreduce[0][0]'), next: Next(scope_id='06824b7e-6a70-724e-8000-9bfff19b28d5', step=0, workflow='summarize_issue')
# {'issue': {'body': '**Description**  \nCurrently, the tool only outputs CSV to stdout. For easier integration with other systems, it would be great to add a `--format json` option that emits JSON.\n\n**Use Case**  \nAllows downstream scripts or services to consume structured JSON output without an extra CSV→JSON conversion step.\n\n**Proposed Solution**  \n1. Add a `--format`/`-f` CLI flag with choices `csv` (default) and `json`.  \n2. Branch in the output routine:  \n   - If `csv`, use the existing writer.  \n   - If `json`, build a list of dicts and call `json.dumps(..., indent=2)`.  \n\n**Alternatives Considered**  \n- Providing a separate `csv-to-json` helper script (less discoverable and requires an extra step).  \n', 'title': 'Add support for JSON output format', 'number': 2}}
# --------------------------------------------------
# Transition index: 13, type: init_branch, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[2].mapreduce[0][0]'), next: Next(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[2].mapreduce[0][0]')
# {'body': '**Description**  \nCurrently, the tool only outputs CSV to stdout. For easier integration with other systems, it would be great to add a `--format json` option that emits JSON.\n\n**Use Case**  \nAllows downstream scripts or services to consume structured JSON output without an extra CSV→JSON conversion step.\n\n**Proposed Solution**  \n1. Add a `--format`/`-f` CLI flag with choices `csv` (default) and `json`.  \n2. Branch in the output routine:  \n   - If `csv`, use the existing writer.  \n   - If `json`, build a list of dicts and call `json.dumps(..., indent=2)`.  \n\n**Alternatives Considered**  \n- Providing a separate `csv-to-json` helper script (less discoverable and requires an extra step).  \n', 'title': 'Add support for JSON output format', 'number': 2}
# --------------------------------------------------
# Transition index: 12, type: init_branch, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[2].mapreduce[0][1]'), next: Next(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='PAR:`main`[2].mapreduce[0][1]')
# {'body': '**Description**  \nRunning the CLI without any arguments causes an unhandled exception and stack trace. Instead, it should display usage help or a clear error message.\n\n**Steps to Reproduce**  \n1. Clone the repo  \n2. Run `python main.py` without any flags or parameters  \n3. Observe an uncaught `IndexError: list index out of range`  \n\n**Expected Behavior**  \nThe CLI prints the help/usage text and exits with an error code (e.g. `exit 1`) rather than crashing.\n\n**Environment**  \n- Python 3.9+  \n- Tested on macOS 12 and Ubuntu 22.04  \n', 'title': 'CLI crashes when no arguments are provided', 'number': 1}
# --------------------------------------------------
# Transition index: 11, type: step, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=1, workflow='main'), next: Next(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=2, workflow='main')
# {'all_labels': ['bug', 'documentation', 'duplicate', 'enhancement', 'good first issue', 'help wanted', 'invalid', 'question', 'wontfix']}
# --------------------------------------------------
# Transition index: 10, type: finish_branch, current: Current(scope_id='06824b7e-4432-7d51-8000-1436bceef215', step=1, workflow='fetch_labels'), next: None
# {'all_labels': ['bug', 'documentation', 'duplicate', 'enhancement', 'good first issue', 'help wanted', 'invalid', 'question', 'wontfix']}
# --------------------------------------------------
# Transition index: 9, type: step, current: Current(scope_id='06824b7e-4432-7d51-8000-1436bceef215', step=0, workflow='fetch_labels'), next: Next(scope_id='06824b7e-4432-7d51-8000-1436bceef215', step=1, workflow='fetch_labels')
# {'json': [{'id': 8600760474, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/labels/bug', 'name': 'bug', 'color': 'd73a4a', 'default': True, 'node_id': 'LA_kwDOOoq64c8AAAACAKUwmg', 'description': "Something isn't working"}, {'id': 8600760483, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/labels/documentation', 'name': 'documentation', 'color': '0075ca', 'default': True, 'node_id': 'LA_kwDOOoq64c8AAAACAKUwow', 'description': 'Improvements or additions to documentation'}, {'id': 8600760496, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/labels/duplicate', 'name': 'duplicate', 'color': 'cfd3d7', 'default': True, 'node_id': 'LA_kwDOOoq64c8AAAACAKUwsA', 'description': 'This issue or pull request already exists'}, {'id': 8600760509, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/labels/enhancement', 'name': 'enhancement', 'color': 'a2eeef', 'default': True, 'node_id': 'LA_kwDOOoq64c8AAAACAKUwvQ', 'description': 'New feature or request'}, {'id': 8600760533, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/labels/good%20first%20issue', 'name': 'good first issue', 'color': '7057ff', 'default': True, 'node_id': 'LA_kwDOOoq64c8AAAACAKUw1Q', 'description': 'Good for newcomers'}, {'id': 8600760522, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/labels/help%20wanted', 'name': 'help wanted', 'color': '008672', 'default': True, 'node_id': 'LA_kwDOOoq64c8AAAACAKUwyg', 'description': 'Extra attention is needed'}, {'id': 8600760545, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/labels/invalid', 'name': 'invalid', 'color': 'e4e669', 'default': True, 'node_id': 'LA_kwDOOoq64c8AAAACAKUw4Q', 'description': "This doesn't seem right"}, {'id': 8600760559, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/labels/question', 'name': 'question', 'color': 'd876e3', 'default': True, 'node_id': 'LA_kwDOOoq64c8AAAACAKUw7w', 'description': 'Further information is requested'}, {'id': 8600760564, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/labels/wontfix', 'name': 'wontfix', 'color': 'ffffff', 'default': True, 'node_id': 'LA_kwDOOoq64c8AAAACAKUw9A', 'description': 'This will not be worked on'}], 'content': '...', 'headers': {'date': 'Wed, 14 May 2025 15:33:57 GMT', 'etag': 'W/"75d5e3fe292d99d8487be490927c68e3ed27d6e52d67afa611daab3e38620c76"', 'vary': 'Accept, Authorization, Cookie, X-GitHub-OTP,Accept-Encoding, Accept, X-Requested-With', 'server': 'github.com', 'content-type': 'application/json; charset=utf-8', 'cache-control': 'private, max-age=60, s-maxage=60', 'x-oauth-scopes': 'admin:enterprise, admin:gpg_key, admin:org, admin:org_hook, admin:public_key, admin:repo_hook, admin:ssh_signing_key, audit_log, codespace, copilot, delete:packages, gist, notifications, project, repo, user, workflow, write:discussion, write:network_configurations, write:packages', 'referrer-policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'x-frame-options': 'deny', 'content-encoding': 'gzip', 'x-ratelimit-used': '11', 'x-xss-protection': '0', 'transfer-encoding': 'chunked', 'x-ratelimit-limit': '5000', 'x-ratelimit-reset': '1747238377', 'x-github-media-type': 'github.v3; format=json', 'x-github-request-id': 'E5AE:3F7EFC:1AF3D4:35F436:6824B7E4', 'x-ratelimit-resource': 'core', 'x-ratelimit-remaining': '4989', 'x-content-type-options': 'nosniff', 'content-security-policy': "default-src 'none'", 'x-accepted-oauth-scopes': 'repo', 'strict-transport-security': 'max-age=31536000; includeSubdomains; preload', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media- ...
# --------------------------------------------------
# Transition index: 8, type: init_branch, current: Current(scope_id='06824b7e-4432-7d51-8000-1436bceef215', step=0, workflow='fetch_labels'), next: Next(scope_id='06824b7e-4432-7d51-8000-1436bceef215', step=0, workflow='fetch_labels')
# {'repo_name': 'Julep-Github-Issue-Tagger', 'repo_owner': 'anasalatasiuni'}
# --------------------------------------------------
# Transition index: 7, type: step, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=1, workflow='main'), next: Next(scope_id='06824b7e-4432-7d51-8000-1436bceef215', step=0, workflow='fetch_labels')
# {'repo_name': 'Julep-Github-Issue-Tagger', 'repo_owner': 'anasalatasiuni'}
# --------------------------------------------------
# Transition index: 6, type: step, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='main'), next: Next(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=1, workflow='main')
# {'issues': [{'body': '**Description**  \nCurrently, the tool only outputs CSV to stdout. For easier integration with other systems, it would be great to add a `--format json` option that emits JSON.\n\n**Use Case**  \nAllows downstream scripts or services to consume structured JSON output without an extra CSV→JSON conversion step.\n\n**Proposed Solution**  \n1. Add a `--format`/`-f` CLI flag with choices `csv` (default) and `json`.  \n2. Branch in the output routine:  \n   - If `csv`, use the existing writer.  \n   - If `json`, build a list of dicts and call `json.dumps(..., indent=2)`.  \n\n**Alternatives Considered**  \n- Providing a separate `csv-to-json` helper script (less discoverable and requires an extra step).  \n', 'title': 'Add support for JSON output format', 'number': 2}, {'body': '**Description**  \nRunning the CLI without any arguments causes an unhandled exception and stack trace. Instead, it should display usage help or a clear error message.\n\n**Steps to Reproduce**  \n1. Clone the repo  \n2. Run `python main.py` without any flags or parameters  \n3. Observe an uncaught `IndexError: list index out of range`  \n\n**Expected Behavior**  \nThe CLI prints the help/usage text and exits with an error code (e.g. `exit 1`) rather than crashing.\n\n**Environment**  \n- Python 3.9+  \n- Tested on macOS 12 and Ubuntu 22.04  \n', 'title': 'CLI crashes when no arguments are provided', 'number': 1}]}
# --------------------------------------------------
# Transition index: 5, type: finish_branch, current: Current(scope_id='06824b7e-22ed-723d-8000-c93737df05b9', step=1, workflow='fetch_issues'), next: None
# {'issues': [{'body': '**Description**  \nCurrently, the tool only outputs CSV to stdout. For easier integration with other systems, it would be great to add a `--format json` option that emits JSON.\n\n**Use Case**  \nAllows downstream scripts or services to consume structured JSON output without an extra CSV→JSON conversion step.\n\n**Proposed Solution**  \n1. Add a `--format`/`-f` CLI flag with choices `csv` (default) and `json`.  \n2. Branch in the output routine:  \n   - If `csv`, use the existing writer.  \n   - If `json`, build a list of dicts and call `json.dumps(..., indent=2)`.  \n\n**Alternatives Considered**  \n- Providing a separate `csv-to-json` helper script (less discoverable and requires an extra step).  \n', 'title': 'Add support for JSON output format', 'number': 2}, {'body': '**Description**  \nRunning the CLI without any arguments causes an unhandled exception and stack trace. Instead, it should display usage help or a clear error message.\n\n**Steps to Reproduce**  \n1. Clone the repo  \n2. Run `python main.py` without any flags or parameters  \n3. Observe an uncaught `IndexError: list index out of range`  \n\n**Expected Behavior**  \nThe CLI prints the help/usage text and exits with an error code (e.g. `exit 1`) rather than crashing.\n\n**Environment**  \n- Python 3.9+  \n- Tested on macOS 12 and Ubuntu 22.04  \n', 'title': 'CLI crashes when no arguments are provided', 'number': 1}]}
# --------------------------------------------------
# Transition index: 4, type: step, current: Current(scope_id='06824b7e-22ed-723d-8000-c93737df05b9', step=0, workflow='fetch_issues'), next: Next(scope_id='06824b7e-22ed-723d-8000-c93737df05b9', step=1, workflow='fetch_issues')
# {'json': [{'id': 3057016811, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/issues/2', 'body': '**Description**  \nCurrently, the tool only outputs CSV to stdout. For easier integration with other systems, it would be great to add a `--format json` option that emits JSON.\n\n**Use Case**  \nAllows downstream scripts or services to consume structured JSON output without an extra CSV→JSON conversion step.\n\n**Proposed Solution**  \n1. Add a `--format`/`-f` CLI flag with choices `csv` (default) and `json`.  \n2. Branch in the output routine:  \n   - If `csv`, use the existing writer.  \n   - If `json`, build a list of dicts and call `json.dumps(..., indent=2)`.  \n\n**Alternatives Considered**  \n- Providing a separate `csv-to-json` helper script (less discoverable and requires an extra step).  \n', 'user': {'id': 112978092, 'url': 'https://api.github.com/users/anasalatasiuni', 'type': 'User', 'login': 'anasalatasiuni', 'node_id': 'U_kgDOBrvorA', 'html_url': 'https://github.com/anasalatasiuni', 'gists_url': 'https://api.github.com/users/anasalatasiuni/gists{/gist_id}', 'repos_url': 'https://api.github.com/users/anasalatasiuni/repos', 'avatar_url': 'https://avatars.githubusercontent.com/u/112978092?v=4', 'events_url': 'https://api.github.com/users/anasalatasiuni/events{/privacy}', 'site_admin': False, 'gravatar_id': '', 'starred_url': 'https://api.github.com/users/anasalatasiuni/starred{/owner}{/repo}', 'followers_url': 'https://api.github.com/users/anasalatasiuni/followers', 'following_url': 'https://api.github.com/users/anasalatasiuni/following{/other_user}', 'user_view_type': 'public', 'organizations_url': 'https://api.github.com/users/anasalatasiuni/orgs', 'subscriptions_url': 'https://api.github.com/users/anasalatasiuni/subscriptions', 'received_events_url': 'https://api.github.com/users/anasalatasiuni/received_events'}, 'state': 'open', 'title': 'Add support for JSON output format', 'labels': [], 'locked': False, 'number': 2, 'node_id': 'I_kwDOOoq64c62Nl_r', 'assignee': None, 'comments': 0, 'html_url': 'https://github.com/anasalatasiuni/Julep-Github-Issue-Tagger/issues/2', 'assignees': [], 'closed_at': None, 'closed_by': None, 'milestone': None, 'reactions': {'+1': 0, '-1': 0, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/issues/2/reactions', 'eyes': 0, 'heart': 0, 'laugh': 0, 'hooray': 0, 'rocket': 0, 'confused': 0, 'total_count': 0}, 'created_at': '2025-05-12T13:38:09Z', 'events_url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/issues/2/events', 'labels_url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/issues/2/labels{/name}', 'updated_at': '2025-05-14T15:13:27Z', 'comments_url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/issues/2/comments', 'state_reason': None, 'timeline_url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/issues/2/timeline', 'repository_url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger', 'active_lock_reason': None, 'author_association': 'OWNER', 'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0}, 'performed_via_github_app': None}, {'id': 3057015408, 'url': 'https://api.github.com/repos/anasalatasiuni/Julep-Github-Issue-Tagger/issues/1', 'body': '**Description**  \nRunning the CLI without any arguments causes an unhandled exception and stack trace. Instead, it should display usage help or a clear error message.\n\n**Steps to Reproduce**  \n1. Clone the repo  \n2. Run `python main.py` without any flags or parameters  \n3. Observe an uncaught `IndexError: list index out of range`  \n\n**Expected Behavior**  \nThe CLI prints the help/usage text and exits with an error code (e.g. `exit 1`) rather than crashing.\n\n**Environment**  \n- Python 3.9+  \n- Tested on macOS 12 and Ubuntu 22.04  \n', 'user': {'id': 112978092, 'url': 'https://api.github.com/users/anasalatasiuni', 'type': 'User', 'log ...
# --------------------------------------------------
# Transition index: 3, type: init_branch, current: Current(scope_id='06824b7e-22ed-723d-8000-c93737df05b9', step=0, workflow='fetch_issues'), next: Next(scope_id='06824b7e-22ed-723d-8000-c93737df05b9', step=0, workflow='fetch_issues')
# {'repo_name': 'Julep-Github-Issue-Tagger', 'max_issues': 2, 'repo_owner': 'anasalatasiuni'}
# --------------------------------------------------
# Transition index: 2, type: step, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='main'), next: Next(scope_id='06824b7e-22ed-723d-8000-c93737df05b9', step=0, workflow='fetch_issues')
# {'repo_name': 'Julep-Github-Issue-Tagger', 'max_issues': 2, 'repo_owner': 'anasalatasiuni'}
# --------------------------------------------------
# Transition index: 1, type: init, current: Current(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='main'), next: Next(scope_id='06824b7e-1a80-7d7f-8000-731278de234e', step=0, workflow='main')
# {'repo_name': 'Julep-Github-Issue-Tagger', 'max_issues': 2, 'repo_owner': 'anasalatasiuni'}
# --------------------------------------------------
